# %% [markdown]
# ЦЕЛЬ РАБОТЫ: научиться визуализировать данные датасета с помощью графиков
#
# ХОД РАБОТЫ:

# %%
import matplotlib.pyplot as plt

x = [4800, 3657, 2700, 2200]
y = [0, 1, 2, 3]

plt.plot(x, y, color = 'blue', marker = '.', markersize = 10, label = "Линейный график1")
plt.xlabel('DPS (SINGLE TARGET)')
plt.ylabel('NAME')
plt.grid()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [13000, 1142, 5800, 4600]
y = [0, 1, 2, 3]

plt.plot(x, y, color = 'purple', marker = '.', markersize = 10, label = "Линейный график2")
plt.xlabel('DPS (MULTI TARGET)')
plt.ylabel('NAME')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# 1) удалось создать линейные графики
#
# в первом случае был создан график с соотношением первых четырех строк из столбца NAME и их SINGLE TARGET DPS.
#
# во втором случае также был создан график с соотношением первых четырех строк из столбца NAME но уже с MULTI TARGET DPS.
#
# (извините создать минимум 3 шутки не получилось из-за датасета)

# %%
import matplotlib.pyplot as plt

x = ['Zenith', 'Last Prism', 'Star Wrath', 'Terrarian']
y = [4800, 3657, 2700, 2200]

plt.bar(x, y, color = 'blue', label = "Столбчатая диаграмма1")
plt.xlabel('NAME')
plt.ylabel('DPS (SINGLE TARGET)')
plt.title('Пример столбчатой диаграммы')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['Zenith', 'Last Prism', 'Star Wrath', 'Terrarian']
y = [13000, 1142, 5800, 4600]

plt.bar(x, y, color = 'purple', label = "Столбчатая диаграмма2")
plt.xlabel('NAME')
plt.ylabel('DPS (MULTI TARGET)')
plt.title('Пример столбчатой диаграммы')
plt.legend()
plt.show()

# %% [markdown]
# 2) удалось создать столбчатые диаграммы
#
# в первом случае была создана диаграмма с соотношением первых четырех строк из столбца NAME и их SINGLE TARGET DPS.
#
# во втором случае также была создана диаграмма с соотношением первых четырех строк из столбца NAME но уже с MULTI TARGET DPS.
#
# (извините создать минимум 3 шутки не получилось из-за датасета)

# %%
import matplotlib.pyplot as plt

vals = [8, 8, 8, 10]
labels = ['Finch Staff', 'Flameburst Rod', 'Flinx Staff', 'Lightning Aura Rod']

plt.pie(vals, labels = labels)
plt.title("TERRARIA (SINGLE TARGET)")
plt.show()

# %%
import matplotlib.pyplot as plt

vals = [24, 70, 18, 25]
labels = ['Finch Staff', 'Flameburst Rod', 'Flinx Staff', 'Lightning Aura Rod']

plt.pie(vals, labels = labels)
plt.title("TERRARIA (MULTI TARGET)")
plt.show()

# %% [markdown]
# 3) удалось создать две круговые диаграммы
#
# в первом случае взяла последние 4 строки колонки NAME из датасета и также последние 4 значения из столбца DPS (SINGLE TARGET) и привела их к круговой диаграмме
#
# во втором случае все тоже самое но из столбца DPS (MULTI TARGET)

# %%
import matplotlib.pyplot as plt

x = [4800, 3657, 2700, 2200]
y = [0, 1, 2, 3]

plt.scatter(x, y)
plt.xlabel('DPS (SINGLE TARGET)')
plt.ylabel('NAME')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [13000, 1142, 5800, 4600]
y = [0, 1, 2, 3]

plt.scatter(x, y, color = 'purple')
plt.xlabel('DPS (MULTI TARGET)')
plt.ylabel('NAME')
plt.show()

# %% [markdown]
# 4) удалось создать диаграмму рассеивания взяв значения из двух столбцов DPS (multi and single target).
#
# опять же удалось создать только две, потому что датасет не позволяет сделать больше

# %%
import matplotlib.pyplot as plt

x = x = [4800, 3657, 2700, 2200]
y = [0, 1, 2, 3]

plt.hist(x, y, color = 'blue', edgecolor = 'black')
plt.title('Пример гистрограммы')
plt.xlabel('DPS (SINGLE TARGET)')
plt.ylabel('NAME')
plt.show()

# %% [markdown]
# 5) ну с гистограммой не совсем удалось научиться работать, увы, что-то явно пошло не так :с

# %% [markdown]
# ВЫВОД: удалось научиться работать с визуализацией датасета (почти)
